# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# Practice
# genio@Ghost-OS:~$ cd Desktop/lab2
# genio@Ghost-OS:~/Desktop/lab2$ cut -d' ' -f1 file1.txt~
# cut: file1.txt~: No such file or directory
# genio@Ghost-OS:~/Desktop/lab2$ cut -d' ' -f1 file1.txt
# Rahim
# Karim
# genio@Ghost-OS:~/Desktop/lab2$
# genio@Ghost-OS:~/Desktop/lab2$ cut -d' ' -f2 file1.txt
# CSE
# EEE
# genio@Ghost-OS:~/Desktop/lab2$ cut -d' ' -f1,f2 file1.txt
# cut: invalid field value ‘f2’
# Try 'cut --help' for more information.
# genio@Ghost-OS:~/Desktop/lab2$ cut -d' ' -f1,2 file1.txt
# Rahim CSE
# Karim EEE
# genio@Ghost-OS:~/Desktop/lab2$ cut -d' ' -f1,3 file1.txt
# Rahim 120
# Karim 80
# genio@Ghost-OS:~/Desktop/lab2$ cut -d' ' -f1,2,3 file1.txt
# Rahim CSE 120
# Karim EEE 80
# genio@Ghost-OS:~/Desktop/lab2$ cat file1.txt
# Rahim CSE 120
# Karim EEE 80
# genio@Ghost-OS:~/Desktop/lab2$ history
#     1  pwd
#     2  cd ..
#     3  ls
#     4  cd ..
#     5  ls
#     6   cd home
#     7  ls
#     8  cd genio
#     9  ls
#    10  cd Desktop
#    11  ls
#    12  mkdir lab2
#    13  cd lab2
#    14  touch file1.txt
#    15  ls
#    16  touch file3.c
#    17  cat >> file3.c
#    18  cat > file3.c
#    19  nano file3.c
#    20  cat file3.c
#    21  run file3.c
#    22  curl -fsS https://dl.brave.com/install.sh | sh
#    23  pwd
#    24  /home/genio/Documents/Code/p1
#    25  /usr/bin/python /home/genio/Documents/Code/p2.py
#    26   /usr/bin/env /bin/sh /tmp/Microsoft-MIEngine-Cmd-gydf0jtz.lp2
#    27  cd Desktop/lab2
#    28  cut -d' ' -f1 file1.txt~
#    29  cut -d' ' -f1 file1.txt
#    30  cut -d' ' -f2 file1.txt
#    31  cut -d' ' -f1,f2 file1.txt
#    32  cut -d' ' -f1,2 file1.txt
#    33  cut -d' ' -f1,3 file1.txt
#    34  cut -d' ' -f1,2,3 file1.txt
#    35  cat file1.txt
#    36  history
