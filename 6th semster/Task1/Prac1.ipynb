# %%
file_path = "try.txt"

with open(file_path, "w", encoding="utf-8") as f:
    data = []
    for i in range(2, 300, 3):
        f.write(f"{str(i)}\n")

# %%
def linear_search (list, target):
    index = 0
    for i in list:
        index += 1
        if target == i:
            return index 
    
    print(f"{target} is not found!")
    return -1

# %%
file_path = "try.txt"

target = int(input("Enter a number from 2 - 300, to find it's index\n> "))

index = -1
with open(file_path, "r", encoding="utf-8") as f:
    data = f.readlines()
    index = linear_search (data, target)


if index != -1:
    print(f"{target} is found at \n> {index} index/line")

else:
    print("Sorry")
# Out:
# 74 is not found!
# Sorry

# %%
def linear_search (list, target):
    index = 0
    for i in list:
        index += 1
        if target == i:
            return index 

    return -1
# Out:
# 74 is found at
# > 25 index/line

# %%
def lin_ser_with_file(path, target):
    path = "try.txt"

    target = int(input("Enter a number from 2 - 300, to find it's index\n> ").strip())

    index = -1
    with open(path, "r", encoding="utf-8") as f:
        data = f.readlines()
        index = linear_search ([int(i.strip()) for i in data], target)


    if index != -1:
        print(f"{target} is found at \n> {index} index/line")

    else:
        print("Sorry")
        print(f"{target} is not found!")

# %%
if __name__ == "__main__":


    print("\n=====linear_search with from file====\n\n")
    file_path = "try.txt"
    lin_ser_with_file(file_path,input("> "))
# Out:
# =====linear_search with from file====
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       2
#       3
#       4     print("\n=====linear_search with from file====\n\n")
#       5     file_path = "try.txt"
# ----> 6     lin_ser_with_file(file_path,input("> "))
#       7
#       8
#
# NameError: name 'lin_ser_with_file' is not defined
